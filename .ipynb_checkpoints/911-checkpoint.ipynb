# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('911.csv')

# %%
df
# Out:
#               lat        lng  \
# 0       40.297876 -75.581294
# 1       40.258061 -75.264680
# 2       40.121182 -75.351975
# 3       40.116153 -75.343513
# 4       40.251492 -75.603350
# ...           ...        ...
# 115206  40.265484 -75.293554
# 115207  40.131681 -75.389806
# 115208  40.186753 -75.143373
# 115209  40.155928 -75.141169
# 115210  40.147850 -75.333684
#
#                                                      desc      zip  \
# 0       REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1       BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2       HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3       AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4       CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                   ...      ...
# 115206  WERNER RD & ORVILLA RD;  HATFIELD TOWNSHIP; St...  19440.0
# ...

# %%
df_plot=df[['twp','Reason','hour','month','day of week','Year']]

# %%
df_plot['ntitle']=df['title'].str.split(':').str[0]
# Out:
# <ipython-input-16-a44c53e7b962>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot['ntitle']=df['title'].str.split(':').str[0]

# %%
df_plot
# Out:
#                       twp   Reason  hour  month day of week  Year   ntitle
# 0             NEW HANOVER      EMS    17     12         Thu  2015      EMS
# 1       HATFIELD TOWNSHIP      EMS    17     12         Thu  2015      EMS
# 2              NORRISTOWN     Fire    14     12         Thu  2015     Fire
# 3              NORRISTOWN      EMS    16     12         Thu  2015      EMS
# 4        LOWER POTTSGROVE      EMS    16     12         Thu  2015      EMS
# ...                   ...      ...   ...    ...         ...   ...      ...
# 115206  HATFIELD TOWNSHIP      EMS    16     10         Wed  2016      EMS
# 115207      WEST NORRITON      EMS    16     10         Wed  2016      EMS
# 115208            HORSHAM  Traffic    16     10         Wed  2016  Traffic
# 115209     UPPER MORELAND  Traffic    16     10         Wed  2016  Traffic
# 115210      EAST NORRITON  Traffic    16     10         Wed  2016  Traffic
#
# [115211 rows x 7 columns]

# %%
df_plot['ntitle'].value_counts()
# Out:
# EMS        56986
# Traffic    40830
# Fire       17395
# Name: ntitle, dtype: int64

# %% [markdown]
# ## Drop New Column again as the same as Reason

# %%
df_plot.drop('ntitle',axis=1,inplace=True)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
sns.set(rc={'figure.figsize':[10,4]},font_scale=1.3)
for col in df_plot.select_dtypes(exclude=['O','bool']):
    sns.displot(df_plot[col],bins=20,kde=True,color='r')

# %%
for col in df_plot.select_dtypes(include='O'):
        plt.title(col)
        sns.countplot(data=df_plot,x=col,palette='Accent')
        plt.show()

# %%
df_plot
# Out:
#                       twp   Reason  hour  month day of week  Year
# 0             NEW HANOVER      EMS    17     12         Thu  2015
# 1       HATFIELD TOWNSHIP      EMS    17     12         Thu  2015
# 2              NORRISTOWN     Fire    14     12         Thu  2015
# 3              NORRISTOWN      EMS    16     12         Thu  2015
# 4        LOWER POTTSGROVE      EMS    16     12         Thu  2015
# ...                   ...      ...   ...    ...         ...   ...
# 115206  HATFIELD TOWNSHIP      EMS    16     10         Wed  2016
# 115207      WEST NORRITON      EMS    16     10         Wed  2016
# 115208            HORSHAM  Traffic    16     10         Wed  2016
# 115209     UPPER MORELAND  Traffic    16     10         Wed  2016
# 115210      EAST NORRITON  Traffic    16     10         Wed  2016
#
# [115211 rows x 6 columns]

# %%
for col in df_plot.select_dtypes(include='O'):
        plt.title(col+' & Reason')
        sns.countplot(data=df_plot,x=col,hue='Reason',palette='mako')
        plt.show()
